# %% [markdown]
# #PyTorch Workflow
#
# Exploring an example of end to end PyTorch workflow example

# %% [markdown]
# ##What is covered
# 1. Data- preparing and loading data
# 2. Building Model
# 3. Fitting the model to data
# 4. Making predictions and evaluating it
# 5. Saving and loading a model

# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '2.5.1+cpu'

# %% [markdown]
# ###1. Data- Preparing and Loading

# %% [markdown]
# We will create from data from the linear regression formula

# %%
#creating the known values
weight=0.7
bias=0.3

#create
start=0
end=1
step=0.02
X=torch.arange(start,end,step).unsqueeze(dim=1)
y=weight*X+bias

X[:10],y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
len(X),len(y)
# Out:
# (50, 50)

# %%
#splitting data into training and test datasets
train_split=int(0.8*len(X))
X_train,y_train=X[:train_split],y[:train_split]
X_test,y_test=X[train_split:],y[train_split:]

len(X_train),len(y_train)
# Out:
# (40, 40)

# %%
def plot_predictions(train_data=X_train,train_labels=y_train,test_data=X_test,test_labels=y_test,predictions=None):
  """
  Plots training data, test data,and compares predictions
  """
  plt.figure(figsize=(10,7))
  #plot training data
  plt.scatter(train_data,train_labels,c='b',s=4,label="Training data")

  #plot test data
  plt.scatter(test_data,test_labels,c='g',s=4,label="Testing data")

  #plot predictions if they exist
  if predictions is not None:
    plt.scatter(test_data,predictions,c="r",s=4,label="Predictions")

  plt.legend(prop={'size':14})

# %%
plot_predictions()

# %% [markdown]
# ###2. Building the first Model

# %%
#creating linear regression model class

class LinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.weights=nn.Parameter(torch.randn(1,requires_grad=True, #start with random values and store the gradient to implement gradient descent
                                          dtype=torch.float))
    self.bias=nn.Parameter(torch.randn(1,requires_grad=True, #start with random values and store gradients to implement gradient descent
                                       dtype=torch.float))

  #forward method to define the computation in the model
  def forward(self, x:torch.Tensor) -> torch.Tensor: #takes in x the input and converts it into a torch tensor
    return self.weights*x + self.bias #returns the linear regression formula

# %% [markdown]
# Pytroch Model Building Essential
#
# 1. torch.nn - contains all of the buildings for computational graphs
# 2. torch.nn.Parameter - what parameters should our model try and learn
# 3. torch.nn.Module - the base class for all neural network modules
# 4. torch.optim - where the optimizers in PyTorch live they help with gradient descent
# 5. def forward() - forward prop module for the computation that the model has to do

# %%
#create random seed
torch.manual_seed(42)

#create an instance of the model
model_0=LinearRegressionModel()

 #checking the parameters
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
#listing named parameters
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %% [markdown]
# ###Making Predictions
#
# We will make predictions using torch.inference_mode()

# %%
#make predictions
with torch.inference_mode(): #inference mode turns off the gradient tracking
  y_preds=model_0(X_test)

y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %% [markdown]
# Use `torch.inference_mode()` to make predictions not for training

# %%
y_preds_no_grad=model_0(X_test)
y_preds_no_grad
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]], grad_fn=<AddBackward0>)

# %%
y_test
# Out:
# tensor([[0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
#         [0.9860]])

# %%
plot_predictions(predictions=y_preds)

# %% [markdown]
# ###Training the model
#
# For PyTorch we need
# 1. A training loop
# 2. A testing loop

# %%
#setting up a loss function and optimizer
loss_fn=nn.L1Loss() #mean abs error

optimizer=torch.optim.SGD(params=model_0.parameters(),
                         lr=0.01,
                         momentum=0.9)

# %% [markdown]
# ###Building a Training Loop
#
# What the loop does:
# 1. Loop through the data
# 2. Implement the forward pass
# 3. Calculate the loss after the forward pass
# 4. Backward propagation step
# 5. Optimizer minimizes the loss

# %%
torch.manual_seed(42)
epochs=100


epoch_count=[]
training_loss=[]
testing_loss=[]

#1. Looping through the data
for epoch in range(epochs):
  epoch_count.append(epoch)
  #set the model to training mode
  model_0.train()

  #2. forward pass
  y_pred=model_0(X_train)

  #3. calculating loss
  loss=loss_fn(y_pred,y_train)
  training_loss.append(loss)
  #print(f"The loss is : {loss}")
  optimizer.zero_grad() #to prevent accumulation of gradient by optimizer in each epoch

  #4. Backprop
  loss.backward()

  #5. optimizing
  optimizer.step()

  ###testing
  model_0.eval()
  with torch.inference_mode():
    test_pred=model_0(X_test)
    test_loss=loss_fn(test_pred,y_test)
    testing_loss.append(test_loss)

  if epoch%10==0:
    print(f" Epoch: {epoch} | Loss: {loss} | Test Loss: {test_loss}")
    print(model_0.state_dict())
# Out:
#  Epoch: 0 | Loss: 0.31288138031959534 | Test Loss: 0.48106518387794495
# OrderedDict({'weights': tensor([0.3406]), 'bias': tensor([0.1388])})
#  Epoch: 10 | Loss: 0.10313145816326141 | Test Loss: 0.026505161076784134
# OrderedDict({'weights': tensor([0.4982]), 'bias': tensor([0.5061])})
#  Epoch: 20 | Loss: 0.06960087269544601 | Test Loss: 0.1943041831254959
# OrderedDict({'weights': tensor([0.4652]), 'bias': tensor([0.3147])})
#  Epoch: 30 | Loss: 0.04656733572483063 | Test Loss: 0.027078520506620407
# OrderedDict({'weights': tensor([0.5785]), 'bias': tensor([0.3811])})
#  Epoch: 40 | Loss: 0.021285563707351685 | Test Loss: 0.001966828014701605
# OrderedDict({'weights': tensor([0.6690]), 'bias': tensor([0.3293])})
#  Epoch: 50 | Loss: 0.015717655420303345 | Test Loss: 0.0101406155154109
# OrderedDict({'weights': tensor([0.7189]), 'bias': tensor([0.2730])})
#  Epoch: 60 | Loss: 0.009445302188396454 | Test Loss: 0.0240285936743021
# OrderedDict({'weights': tensor([0.7263]), 'bias': tensor([0.3007])})
#  Epoch: 70 | Loss: 0.00741451233625412 | Test Loss: 0.007351106498390436
# OrderedDict({'weights': tensor([0.6937]), 'bias': tensor([0.2983])})
#  Epoch: 80 | Loss: 0.0018297791248187423 | Test Loss: 0.00930970348417759
# OrderedDict({'weights': tensor([0.6994]), 'bias': tensor([0.3098])})
#  Epoch: 90 | Loss: 0.004054549150168896 | Test Loss: 0.004079192876815796
# OrderedDict({'weights': tensor([0.7076]), 'bias': tensor([0.2892])})

# %%
with torch.inference_mode():
  y_preds=model_0(X_test)

plot_predictions(predictions=y_preds)

# %%
training_loss,testing_loss
# Out:
# ([tensor(0.3129, grad_fn=<MeanBackward0>),
#   tensor(0.3014, grad_fn=<MeanBackward0>),
#   tensor(0.2795, grad_fn=<MeanBackward0>),
#   tensor(0.2482, grad_fn=<MeanBackward0>),
#   tensor(0.2086, grad_fn=<MeanBackward0>),
#   tensor(0.1614, grad_fn=<MeanBackward0>),
#   tensor(0.1079, grad_fn=<MeanBackward0>),
#   tensor(0.0654, grad_fn=<MeanBackward0>),
#   tensor(0.0509, grad_fn=<MeanBackward0>),
#   tensor(0.0679, grad_fn=<MeanBackward0>),
#   tensor(0.1031, grad_fn=<MeanBackward0>),
#   tensor(0.1274, grad_fn=<MeanBackward0>),
#   tensor(0.1377, grad_fn=<MeanBackward0>),
#   tensor(0.1355, grad_fn=<MeanBackward0>),
#   tensor(0.1220, grad_fn=<MeanBackward0>),
#   tensor(0.0983, grad_fn=<MeanBackward0>),
#   tensor(0.0675, grad_fn=<MeanBackward0>),
#   tensor(0.0483, grad_fn=<MeanBackward0>),
#   tensor(0.0465, grad_fn=<MeanBackward0>),
#   tensor(0.0565, grad_fn=<MeanBackward0>),
#   tensor(0.0696, grad_fn=<MeanBackward0>),
#   tensor(0.0784, grad_fn=<MeanBackward0>),
#   tensor(0.0792, grad_fn=<MeanBackward0>),
#   tensor(0.0713, grad_fn=<MeanBackward0>),
#   tensor(0.0578, grad_fn=<MeanBackward0>),
#   tensor(0.0440, grad_fn=<MeanBackward0>),
#   tensor(0.0355, grad_fn=<MeanBackward0>),
#   tensor(0.0355, grad_fn=<MeanBackward0>),
#   tensor(0.0425, grad_fn=<MeanBackward0>),
#   tensor(0.0488, grad_fn=<MeanBackward0>),
#   tensor(0.0466, grad_fn=<MeanBackward0>),
#   tensor(0.0360, grad_fn=<MeanBackward0>),
#   tensor(0.0262, grad_fn=<MeanBackward0>),
#   tensor(0.0239, grad_fn=<MeanBackward0>),
#   tensor(0.0279, grad_fn=<MeanBackward0>),
#   tensor(0.0320, grad_fn=<MeanBackward0>),
#   tensor(0.0306, grad_fn=<MeanBackward0>),
#   tensor(0.0227, grad_fn=<MeanBackward0>),
#   tensor(0.0140, grad_fn=<MeanBackward0>),
#   tensor(0.0145, grad_fn=<MeanBackward0>),
#   tensor(0.0213, grad_fn=<MeanBackward0>),
#   tensor(0.0171, grad_fn=<MeanBackward0>),
#   tensor(0.0057, grad_fn=<MeanBackward0>),
#   tensor(0.0128, grad_fn=<MeanBackward0>),
#   tensor(0.0145, grad_fn=<MeanBackward0>),
#   tensor(0.0045, grad_fn=<MeanBackward0>),
#   tensor(0.0160, grad_fn=<MeanBackward0>),
#   tensor(0.0230, grad_fn=<MeanBackward0>),
#   tensor(0.0177, grad_fn=<MeanBackward0>),
#   tensor(0.0043, grad_fn=<MeanBackward0>),
#   tensor(0.0157, grad_fn=<MeanBackward0>),
#   tensor(0.0196, grad_fn=<MeanBackward0>),
#   tensor(0.0116, grad_fn=<MeanBackward0>),
#   tensor(0.0084, grad_fn=<MeanBackward0>),
#   tensor(0.0171, grad_fn=<MeanBackward0>),
#   tensor(0.0146, grad_fn=<MeanBackward0>),
#   tensor(0.0064, grad_fn=<MeanBackward0>),
#   tensor(0.0130, grad_fn=<MeanBackward0>),
#   tensor(0.0139, grad_fn=<MeanBackward0>),
#   tensor(0.0058, grad_fn=<MeanBackward0>),
#   tensor(0.0094, grad_fn=<MeanBackward0>),
#   tensor(0.0109, grad_fn=<MeanBackward0>),
#   tensor(0.0041, grad_fn=<MeanBackward0>),
#   tensor(0.0101, grad_fn=<MeanBackward0>),
#   tensor(0.0084, grad_fn=<MeanBackward0>),
#   tensor(0.0046, grad_fn=<MeanBackward0>),
#   tensor(0.0048, grad_fn=<MeanBackward0>),
#   tensor(0.0065, grad_fn=<MeanBackward0>),
#   tensor(0.0052, grad_fn=<MeanBackward0>),
#   tensor(0.0075, grad_fn=<MeanBackward0>),
#   tensor(0.0074, grad_fn=<MeanBackward0>),
#   tensor(0.0042, grad_fn=<MeanBackward0>),
#   tensor(0.0031, grad_fn=<MeanBackward0>),
#   tensor(0.0094, grad_fn=<MeanBackward0>),
#   tensor(0.0091, grad_fn=<MeanBackward0>),
#   tensor(0.0030, grad_fn=<MeanBackward0>),
#   tensor(0.0058, grad_fn=<MeanBackward0>),
#   tensor(0.0029, grad_fn=<MeanBackward0>),
#   tensor(0.0025, grad_fn=<MeanBackward0>),
#   tensor(0.0058, grad_fn=<MeanBackward0>),
#   tensor(0.0018, grad_fn=<MeanBackward0>),
#   tensor(0.0096, grad_fn=<MeanBackward0>),
#   tensor(0.0082, grad_fn=<MeanBackward0>),
#   tensor(0.0047, grad_fn=<MeanBackward0>),
#   tensor(0.0047, grad_fn=<MeanBackward0>),
#   tensor(0.0068, grad_fn=<MeanBackward0>),
#   tensor(0.0057, grad_fn=<MeanBackward0>),
#   tensor(0.0069, grad_fn=<MeanBackward0>),
#   tensor(0.0067, grad_fn=<MeanBackward0>),
#   tensor(0.0050, grad_fn=<MeanBackward0>),
#   tensor(0.0041, grad_fn=<MeanBackward0>),
#   tensor(0.0079, grad_fn=<MeanBackward0>),
#   tensor(0.0071, grad_fn=<MeanBackward0>),
#   tensor(0.0052, grad_fn=<MeanBackward0>),
#   tensor(0.0047, grad_fn=<MeanBackward0>),
#   tensor(0.0058, grad_fn=<MeanBackward0>),
#   tensor(0.0037, grad_fn=<MeanBackward0>),
#   tensor(0.0078, grad_fn=<MeanBackward0>),
#   tensor(0.0066, grad_fn=<MeanBackward0>),
#   tensor(0.0060, grad_fn=<MeanBackward0>)],
#  [tensor(0.4811),
#   tensor(0.4555),
#   tensor(0.4190),
#   tensor(0.3726),
#   tensor(0.3175),
#   tensor(0.2544),
#   tensor(0.1851),
#   tensor(0.1153),
#   tensor(0.0520),
#   tensor(0.0110),
#   tensor(0.0265),
#   tensor(0.0401),
#   tensor(0.0389),
#   tensor(0.0243),
#   tensor(0.0101),
#   tensor(0.0396),
#   tensor(0.0834),
#   tensor(0.1253),
#   tensor(0.1598),
#   tensor(0.1834),
#   tensor(0.1943),
#   tensor(0.1927),
#   tensor(0.1793),
#   tensor(0.1559),
#   tensor(0.1255),
#   tensor(0.0919),
#   tensor(0.0593),
#   tensor(0.0330),
#   tensor(0.0179),
#   tensor(0.0161),
#   tensor(0.0271),
#   tensor(0.0455),
#   tensor(0.0645),
#   tensor(0.0785),
#   tensor(0.0836),
#   tensor(0.0778),
#   tensor(0.0618),
#   tensor(0.0381),
#   tensor(0.0131),
#   tensor(0.0023),
#   tensor(0.0020),
#   tensor(0.0120),
#   tensor(0.0245),
#   tensor(0.0223),
#   tensor(0.0068),
#   tensor(0.0206),
#   tensor(0.0318),
#   tensor(0.0284),
#   tensor(0.0118),
#   tensor(0.0068),
#   tensor(0.0101),
#   tensor(0.0012),
#   tensor(0.0233),
#   tensor(0.0352),
#   tensor(0.0325),
#   tensor(0.0166),
#   tensor(0.0013),
#   tensor(0.0018),
#   tensor(0.0103),
#   tensor(0.0235),
#   tensor(0.0240),
#   tensor(0.0110),
#   tensor(0.0038),
#   tensor(0.0037),
#   tensor(0.0099),
#   tensor(0.0086),
#   tensor(0.0060),
#   tensor(0.0056),
#   tensor(0.0082),
#   tensor(0.0071),
#   tensor(0.0074),
#   tensor(0.0069),
#   tensor(0.0070),
#   tensor(0.0061),
#   tensor(0.0083),
#   tensor(0.0119),
#   tensor(0.0018),
#   tensor(0.0020),
#   tensor(0.0107),
#   tensor(0.0050),
#   tensor(0.0093),
#   tensor(0.0087),
#   tensor(0.0053),
#   tensor(0.0044),
#   tensor(0.0098),
#   tensor(0.0092),
#   tensor(0.0049),
#   tensor(0.0040),
#   tensor(0.0102),
#   tensor(0.0095),
#   tensor(0.0041),
#   tensor(0.0028),
#   tensor(0.0118),
#   tensor(0.0114),
#   tensor(0.0008),
#   tensor(0.0016),
#   tensor(0.0148),
#   tensor(0.0132),
#   tensor(0.0018),
#   tensor(0.0017)])

# %%
plt.plot(epoch_count,np.array(torch.tensor(training_loss).numpy()),label='Training_loss')
plt.plot(epoch_count,np.array(torch.tensor(testing_loss).numpy()),label='Test_loss')
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# ###Saving and loading a model
# There are 3 main methods involved in saving and loading models in PyTorch
#
# 1. `torch.save()` - allows to save the model in python pickle format
# 2. `torch.load()` - allows to load a saved PyTorch object
# 3. `torch.nn.Module.load_state_dict()` - loads a model's saved dictionary

# %%
#saving a model
from pathlib import Path as path

#creating a directory
MODEL_PATH=path('models')
MODEL_PATH.mkdir(parents=True, exist_ok=True)

#create model save path
MODEL_NAME='model_0_linear_regression.pth'
MODEL_SAVE_PATH=MODEL_PATH/MODEL_NAME

#saving model state dict
print(f"saving model to : {MODEL_SAVE_PATH}")
torch.save(obj=model_0.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# saving model to : models\model_0_linear_regression.pth

# %% [markdown]
# Since we saved the `state_dict` we will create a new instance of our model class and load the saved `state_dict`

# %%
#creating a instance of our model class
loaded_model_0=LinearRegressionModel()

# %%
#loading the state_dicts
loaded_model_0.load_state_dict(torch.load(f=MODEL_SAVE_PATH))
# Out:
# C:\Users\ladit\AppData\Local\Temp\ipykernel_51904\2466482691.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model_0.load_state_dict(torch.load(f=MODEL_SAVE_PATH))
# <All keys matched successfully>

# %%
loaded_model_0.eval()
with torch.inference_mode():
  y_preds=loaded_model_0(X_test)

y_preds
# Out:
# tensor([[0.8575],
#         [0.8717],
#         [0.8858],
#         [0.9000],
#         [0.9142],
#         [0.9283],
#         [0.9425],
#         [0.9567],
#         [0.9708],
#         [0.9850]])

# %% [markdown]
# ##Putting all the steps together

# %%
#creating data
weight=0.84
bias=0.29
start=0
end=2
step=0.015
X=torch.arange(start,end,step).unsqueeze(dim=1)
Y=weight*X+bias

# %%
len(X),len(Y)
# Out:
# (134, 134)

# %%
train_test_split=int(0.9*(len(X)))
X_train,Y_train=X[:train_test_split],Y[:train_test_split]
X_test,Y_test=X[train_test_split:],Y[train_test_split:]
len(X_train),len(X_test)
# Out:
# (120, 14)

# %%
plot_predictions(train_data=X_train,train_labels=Y_train,
                 test_data=X_test,test_labels=Y_test,predictions=None)

# %%
class LinearregressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    '''self.weight=nn.Parameter(torch.randn(1,requires_grad=True,
                                        dtype=torch.float))
    self.bias=nn.Parameter(torch.randn(1,requires_grad=True,
                                      dtype=torch.float))'''
    self.linear_layer=nn.Linear(in_features=1,out_features=1,bias=True)
  def forward(self,x:torch.Tensor)->torch.Tensor:
    return self.linear_layer(x)

# %%
model_recap=LinearregressionModel()

model_recap.eval()
with torch.inference_mode():
  y_preds=model_recap(X_test)

plot_predictions(train_data=X_train,train_labels=Y_train,
                 test_data=X_test,test_labels=Y_test,predictions=y_preds)

# %%
loss_fn=nn.L1Loss()

optimizer=torch.optim.SGD(params=model_recap.parameters(),
                          lr=0.01,
                          momentum=0.9)

# %%
epochs=500

epoch_count=[]
training_loss=[]
testing_loss=[]

for epoch in range(epochs):
  epoch_count.append(epoch)
  model_recap.train()
  y_preds=model_recap(X_train)
  loss=loss_fn(y_preds,Y_train)
  training_loss.append(loss)
  optimizer.zero_grad()

  loss.backward()
  optimizer.step()

  model_recap.eval()
  with torch.inference_mode():
    y_preds=model_recap(X_test)
    test_loss=loss_fn(y_preds,Y_test)
    testing_loss.append(test_loss)

  if epoch%10==0:
    print(f"Epoch  {epoch} | Training loss {loss} | Test loss {test_loss}")
    print(model_recap.state_dict())
# Out:
# Epoch  0 | Training loss 1.033459186553955 | Test loss 2.070923328399658
# OrderedDict({'linear_layer.weight': tensor([[-0.2102]]), 'linear_layer.bias': tensor([0.2118])})
# Epoch  10 | Training loss 0.39015036821365356 | Test loss 0.8409934639930725
# OrderedDict({'linear_layer.weight': tensor([[0.2075]]), 'linear_layer.bias': tensor([0.6492])})
# Epoch  20 | Training loss 0.33360207080841064 | Test loss 0.024059627205133438
# OrderedDict({'linear_layer.weight': tensor([[0.5600]]), 'linear_layer.bias': tensor([0.8448])})
# Epoch  30 | Training loss 0.1911288946866989 | Test loss 0.4887254536151886
# OrderedDict({'linear_layer.weight': tensor([[0.4613]]), 'linear_layer.bias': tensor([0.5198])})
# Epoch  40 | Training loss 0.09348748624324799 | Test loss 0.006820738315582275
# OrderedDict({'linear_layer.weight': tensor([[0.7444]]), 'linear_layer.bias': tensor([0.4655])})
# Epoch  50 | Training loss 0.028280526399612427 | Test loss 0.07483820617198944
# OrderedDict({'linear_layer.weight': tensor([[0.8799]]), 'linear_layer.bias': tensor([0.2892])})
# Epoch  60 | Training loss 0.030868899077177048 | Test loss 0.06216893717646599
# OrderedDict({'linear_layer.weight': tensor([[0.8948]]), 'linear_layer.bias': tensor([0.2482])})
# Epoch  70 | Training loss 0.01982880011200905 | Test loss 0.020120961591601372
# OrderedDict({'linear_layer.weight': tensor([[0.8135]]), 'linear_layer.bias': tensor([0.3202])})
# Epoch  80 | Training loss 0.006725386716425419 | Test loss 0.023298485204577446
# OrderedDict({'linear_layer.weight': tensor([[0.8358]]), 'linear_layer.bias': tensor([0.2746])})
# Epoch  90 | Training loss 0.012280387803912163 | Test loss 0.04095979407429695
# OrderedDict({'linear_layer.weight': tensor([[0.8668]]), 'linear_layer.bias': tensor([0.2800])})
# Epoch  100 | Training loss 0.005621642805635929 | Test loss 0.026213398203253746
# OrderedDict({'linear_layer.weight': tensor([[0.8433]]), 'linear_layer.bias': tensor([0.3099])})
# Epoch  110 | Training loss 0.0230365302413702 | Test loss 0.052445702254772186
# OrderedDict({'linear_layer.weight': tensor([[0.8197]]), 'linear_layer.bias': tensor([0.2761])})
# Epoch  120 | Training loss 0.0032615165691822767 | Test loss 0.016832096502184868
# OrderedDict({'linear_layer.weight': tensor([[0.8499]]), 'linear_layer.bias': tensor([0.2881])})
# Epoch  130 | Training loss 0.016473576426506042 | Test loss 0.0018912298837676644
# OrderedDict({'linear_layer.weight': tensor([[0.8301]]), 'linear_layer.bias': tensor([0.3069])})
# Epoch  140 | Training loss 0.006775402929633856 | Test loss 0.030409378930926323
# OrderedDict({'linear_layer.weight': tensor([[0.8596]]), 'linear_layer.bias': tensor([0.2832])})
# Epoch  150 | Training loss 0.034716445952653885 | Test loss 0.02079779841005802
# OrderedDict({'linear_layer.weight': tensor([[0.8291]]), 'linear_layer.bias': tensor([0.2898])})
# Epoch  160 | Training loss 0.02401595562696457 | Test loss 0.046811699867248535
# OrderedDict({'linear_layer.weight': tensor([[0.8528]]), 'linear_layer.bias': tensor([0.3125])})
# Epoch  170 | Training loss 0.0185241736471653 | Test loss 0.03250303491950035
# OrderedDict({'linear_layer.weight': tensor([[0.8285]]), 'linear_layer.bias': tensor([0.2794])})
# Epoch  180 | Training loss 0.03412161022424698 | Test loss 0.0040639895014464855
# OrderedDict({'linear_layer.weight': tensor([[0.8350]]), 'linear_layer.bias': tensor([0.2955])})
# Epoch  190 | Training loss 0.004637526348233223 | Test loss 0.04303032159805298
# OrderedDict({'linear_layer.weight': tensor([[0.8585]]), 'linear_layer.bias': tensor([0.2980])})
# Epoch  200 | Training loss 0.05318058654665947 | Test loss 0.04891281574964523
# OrderedDict({'linear_layer.weight': tensor([[0.8551]]), 'linear_layer.bias': tensor([0.3103])})
# Epoch  210 | Training loss 0.01333981566131115 | Test loss 0.005656301975250244
# OrderedDict({'linear_layer.weight': tensor([[0.8376]]), 'linear_layer.bias': tensor([0.2889])})
# Epoch  220 | Training loss 0.03641311451792717 | Test loss 0.021580619737505913
# OrderedDict({'linear_layer.weight': tensor([[0.8494]]), 'linear_layer.bias': tensor([0.2938])})
# Epoch  230 | Training loss 0.006707308813929558 | Test loss 0.013573884963989258
# OrderedDict({'linear_layer.weight': tensor([[0.8464]]), 'linear_layer.bias': tensor([0.2914])})
# Epoch  240 | Training loss 0.0075003281235694885 | Test loss 0.026243779808282852
# OrderedDict({'linear_layer.weight': tensor([[0.8256]]), 'linear_layer.bias': tensor([0.2912])})
# Epoch  250 | Training loss 0.006543985567986965 | Test loss 0.017512159422039986
# OrderedDict({'linear_layer.weight': tensor([[0.8444]]), 'linear_layer.bias': tensor([0.2992])})
# Epoch  260 | Training loss 0.016448263078927994 | Test loss 0.002293212106451392
# OrderedDict({'linear_layer.weight': tensor([[0.8398]]), 'linear_layer.bias': tensor([0.2880])})
# Epoch  270 | Training loss 0.008022514171898365 | Test loss 0.022285521030426025
# OrderedDict({'linear_layer.weight': tensor([[0.8278]]), 'linear_layer.bias': tensor([0.2909])})
# Epoch  280 | Training loss 0.007221386767923832 | Test loss 0.0021722486708313227
# OrderedDict({'linear_layer.weight': tensor([[0.8431]]), 'linear_layer.bias': tensor([0.2864])})
# Epoch  290 | Training loss 0.004144403152167797 | Test loss 0.021171987056732178
# OrderedDict({'linear_layer.weight': tensor([[0.8464]]), 'linear_layer.bias': tensor([0.2990])})
# Epoch  300 | Training loss 0.013625861145555973 | Test loss 0.003907110076397657
# OrderedDict({'linear_layer.weight': tensor([[0.8413]]), 'linear_layer.bias': tensor([0.2836])})
# Epoch  310 | Training loss 0.004273930564522743 | Test loss 0.027488768100738525
# OrderedDict({'linear_layer.weight': tensor([[0.8528]]), 'linear_layer.bias': tensor([0.2931])})
# Epoch  320 | Training loss 0.013580777682363987 | Test loss 0.0017043607076629996
# OrderedDict({'linear_layer.weight': tensor([[0.8436]]), 'linear_layer.bias': tensor([0.2815])})
# Epoch  330 | Training loss 0.004289543721824884 | Test loss 0.028257029131054878
# OrderedDict({'linear_layer.weight': tensor([[0.8536]]), 'linear_layer.bias': tensor([0.2924])})
# Epoch  340 | Training loss 0.013575424440205097 | Test loss 0.0014362165238708258
# OrderedDict({'linear_layer.weight': tensor([[0.8438]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  350 | Training loss 0.004291321616619825 | Test loss 0.028350677341222763
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  360 | Training loss 0.013574887067079544 | Test loss 0.0014034679625183344
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  370 | Training loss 0.004291570745408535 | Test loss 0.028362009674310684
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  380 | Training loss 0.013574582524597645 | Test loss 0.0013998150825500488
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  390 | Training loss 0.004291689023375511 | Test loss 0.02836318500339985
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  400 | Training loss 0.013574494048953056 | Test loss 0.0013995000626891851
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  410 | Training loss 0.004291856195777655 | Test loss 0.0283630583435297
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  420 | Training loss 0.013574456796050072 | Test loss 0.0013995596673339605
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  430 | Training loss 0.004291856195777655 | Test loss 0.0283630583435297
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  440 | Training loss 0.013574456796050072 | Test loss 0.0013995596673339605
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  450 | Training loss 0.004291856195777655 | Test loss 0.0283630583435297
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  460 | Training loss 0.013574456796050072 | Test loss 0.0013995596673339605
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  470 | Training loss 0.004291856195777655 | Test loss 0.0283630583435297
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})
# Epoch  480 | Training loss 0.013574456796050072 | Test loss 0.0013995596673339605
# OrderedDict({'linear_layer.weight': tensor([[0.8439]]), 'linear_layer.bias': tensor([0.2813])})
# Epoch  490 | Training loss 0.004291856195777655 | Test loss 0.0283630583435297
# OrderedDict({'linear_layer.weight': tensor([[0.8537]]), 'linear_layer.bias': tensor([0.2923])})

# %%
model_recap.eval()
with torch.inference_mode():
  y_preds=model_recap(X_test)

plot_predictions(train_data=X_train,train_labels=Y_train,
                 test_data=X_test,test_labels=Y_test,predictions=y_preds)

# %%
plt.plot(epoch_count,np.array(torch.tensor(training_loss).numpy()),label='Training_loss')
plt.plot(epoch_count,np.array(torch.tensor(testing_loss).numpy()),label='Test_loss')
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
